# %% [markdown]
# <a href="https://colab.research.google.com/github/raj-coding1/EdaAnalysis/blob/main/EDA_imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('/content/imdb_top_1000.csv')
movies.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
movies.drop('Poster_Link',axis = 1, inplace = True)
movies.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
genre = movies.groupby('Genre')

# %%
genre.sum()
# Out:
#                                                                    Series_Title  \
# Genre
# Action, Adventure             The Dark Knight RisesRaiders of the Lost ArkBa...
# Action, Adventure, Biography                           Aguirre, der Zorn Gottes
# Action, Adventure, Comedy     SholayThe GeneralBajrangi BhaijaanGuardians of...
# Action, Adventure, Crime                                              Celda 211
# Action, Adventure, Drama      The Lord of the Rings: The Return of the KingT...
# ...                                                                         ...
# Mystery, Romance, Thriller                                              Vertigo
# Mystery, Sci-Fi, Thriller                               Twelve MonkeysDark City
# Mystery, Thriller             MementoRear WindowShutter IslandKahaaniSleuthT...
# Thriller                                                        Wait Until Dark
# Western                       Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies['Gross']
# Out:
# 0       28,341,469
# 1      134,966,411
# 2      534,858,444
# 3       57,300,000
# 4        4,360,000
#           ...
# 995            NaN
# 996            NaN
# 997     30,500,000
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: object

# %%
genre.sum()['No_of_Votes'].max()
# Out:
# 17720455

# %%
genre.sum()['Gross'].dtypes
# Out:
# dtype('O')

# %%
movies.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
movies['Gross'] = movies['Gross'].str.replace(',','').astype(int)

# %%
movies['Gross'].fillna(method='ffill',inplace = True)
# Out:
# <ipython-input-34-2845258e1065>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   movies['Gross'].fillna(method='ffill',inplace = True)

# %%
movies['Gross'].dtypes
# Out:
# dtype('int64')

# %%
genre = movies.groupby('Genre')

# %%
genre.sum()['Gross'].sort_values(ascending = False).head(3)
# Out:
# Genre
# Action, Adventure, Sci-Fi       5898659459
# Animation, Adventure, Comedy    4603889399
# Action, Adventure, Drama        2714237246
# Name: Gross, dtype: int64

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False)
# Out:
# Genre
# Animation, Drama, War         8.50
# Action, Sci-Fi                8.40
# Drama, Musical                8.40
# Drama, Mystery, War           8.35
# Western                       8.35
#                               ...
# Action, Adventure, Mystery    7.60
# Action, Adventure, Family     7.60
# Action, Adventure, Crime      7.60
# Animation, Drama, Romance     7.60
# Drama, War, Western           7.60
# Name: IMDB_Rating, Length: 202, dtype: float64

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies['Director']
# Out:
# 0            Frank Darabont
# 1      Francis Ford Coppola
# 2         Christopher Nolan
# 3      Francis Ford Coppola
# 4              Sidney Lumet
#                ...
# 995           Blake Edwards
# 996          George Stevens
# 997          Fred Zinnemann
# 998        Alfred Hitchcock
# 999        Alfred Hitchcock
# Name: Director, Length: 1000, dtype: object

# %%
movies['No_of_Votes']
# Out:
# 0      2343110
# 1      1620367
# 2      2303232
# 3      1129952
# 4       689845
#         ...
# 995     166544
# 996      34075
# 997      43374
# 998      26471
# 999      51853
# Name: No_of_Votes, Length: 1000, dtype: int64

# %%
print('Hello World')
# Out:
# Hello World

# %%
#find the director who is most popular:
# Here to find the most popular director we need to take help of no of votes columns
#whoever the most voted will be the most popular

# %%
# $to do that we need to
#we need to groupby with all the director and sum the no of votes for each director and sort it in ascending value
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending = False).head(3)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# Name: No_of_Votes, dtype: int64

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies.head(2)
# Out:
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411

# %%
movies.groupby('Genre')[['Series_Title','IMDB_Rating']].max()
# Out:
#                                           Series_Title  IMDB_Rating
# Genre
# Action, Adventure                The Dark Knight Rises          8.4
# Action, Adventure, Biography  Aguirre, der Zorn Gottes          7.9
# Action, Adventure, Comedy               Thor: Ragnarok          8.2
# Action, Adventure, Crime                     Celda 211          7.6
# Action, Adventure, Drama                  The Revenant          8.9
# ...                                                ...          ...
# Mystery, Romance, Thriller                     Vertigo          8.3
# Mystery, Sci-Fi, Thriller               Twelve Monkeys          8.0
# Mystery, Thriller                    The Lady Vanishes          8.4
# Thriller                               Wait Until Dark          7.8
# Western                         The Outlaw Josey Wales          8.8
#
# [202 rows x 2 columns]

# %%
movies.groupby('Genre')['IMDB_Rating'].max()
# Out:
# Genre
# Action, Adventure               8.4
# Action, Adventure, Biography    7.9
# Action, Adventure, Comedy       8.2
# Action, Adventure, Crime        7.6
# Action, Adventure, Drama        8.9
#                                ...
# Mystery, Romance, Thriller      8.3
# Mystery, Sci-Fi, Thriller       8.0
# Mystery, Thriller               8.4
# Thriller                        7.8
# Western                         8.8
# Name: IMDB_Rating, Length: 202, dtype: float64

# %%
movies.head(2)
# Out:
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411

# %%
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Clint Eastwood       10
# Al Pacino            10
# Leonardo DiCaprio     9
#                      ..
# Gérard Jugnot         1
# Günes Sensoy          1
# Haluk Bilginer        1
# Harriet Andersson     1
# Graham Chapman        1
# Name: Series_Title, Length: 660, dtype: int64

# %%
movies['Genre'].nunique()
# Out:
# 202

# %%
len(movies.groupby('Genre'))
# Out:
# 202

# %%
movies.groupby('Genre').size()
# Out:
# Genre
# Action, Adventure                5
# Action, Adventure, Biography     1
# Action, Adventure, Comedy       10
# Action, Adventure, Crime         1
# Action, Adventure, Drama        14
#                                 ..
# Mystery, Romance, Thriller       1
# Mystery, Sci-Fi, Thriller        2
# Mystery, Thriller                9
# Thriller                         1
# Western                          4
# Length: 202, dtype: int64

# %%
genre = movies.groupby('Genre')

# %%
genre.first()
# Out:
#                                                                Series_Title  \
# Genre
# Action, Adventure                                     The Dark Knight Rises
# Action, Adventure, Biography                       Aguirre, der Zorn Gottes
# Action, Adventure, Comedy                                            Sholay
# Action, Adventure, Crime                                          Celda 211
# Action, Adventure, Drama      The Lord of the Rings: The Return of the King
# ...                                                                     ...
# Mystery, Romance, Thriller                                          Vertigo
# Mystery, Sci-Fi, Thriller                                    Twelve Monkeys
# Mystery, Thriller                                                   Memento
# Thriller                                                    Wait Until Dark
# Western                                     Il buono, il brutto, il cattivo
#
# ...

# %%
genre.nth(6).head(1)
# Out:
#    Series_Title Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# 88       Jagten          2012           R  115 min  Drama          8.3
#
#                                              Overview  Meta_score  \
# 88  A teacher lives a lonely life, all the while s...        77.0
#
#              Director           Star1             Star2              Star3  \
# 88  Thomas Vinterberg  Mads Mikkelsen  Thomas Bo Larsen  Annika Wedderkopp
#
#                Star4  No_of_Votes    Gross
# 88  Lasse Fogelstrøm       281623  687,185

# %%
genre.get_group('Horror')
# Out:
#       Series_Title Released_Year Certificate  Runtime   Genre  IMDB_Rating  \
# 419   The Exorcist          1973           A  122 min  Horror          8.0
# 707  The Innocents          1961           A  100 min  Horror          7.8
#
#                                               Overview  Meta_score  \
# 419  When a 12-year-old girl is possessed by a myst...        81.0
# 707  A young governess for two children becomes con...        88.0
#
#              Director          Star1           Star2         Star3  \
# 419  William Friedkin  Ellen Burstyn   Max von Sydow   Linda Blair
# 707      Jack Clayton   Deborah Kerr  Peter Wyngarde  Megs Jenkins
#
#                 Star4  No_of_Votes        Gross
# 419       Lee J. Cobb       362393  232,906,145
# 707  Michael Redgrave        27007    2,616,000

# %%
genre.groups
# Out:
# {'Action, Adventure': [63, 72, 155, 168, 840], 'Action, Adventure, Biography': [540], 'Action, Adventure, Comedy': [177, 320, 325, 339, 348, 473, 532, 722, 730, 887], 'Action, Adventure, Crime': [909], 'Action, Adventure, Drama': [5, 10, 13, 31, 39, 59, 343, 496, 625, 642, 709, 821, 898, 944], 'Action, Adventure, Family': [927], 'Action, Adventure, Fantasy': [16, 29, 109, 376, 623, 645], 'Action, Adventure, History': [507], 'Action, Adventure, Horror': [535], 'Action, Adventure, Mystery': [914], 'Action, Adventure, Romance': [564], 'Action, Adventure, Sci-Fi': [8, 60, 106, 223, 262, 357, 477, 479, 482, 493, 502, 582, 583, 634, 677, 737, 746, 749, 807, 839, 982], 'Action, Adventure, Thriller': [368, 725, 751, 861, 963], 'Action, Adventure, War': [854, 856], 'Action, Adventure, Western': [543, 865], 'Action, Biography, Crime': [142, 702, 985], 'Action, Biography, Drama': [57, 216, 217, 351, 659, 889, 924], 'Action, Comedy, Crime': [140, 160, 161, 294, 569, 908], 'Action, Comedy, Fantas
# ...

# %%
genre.describe()
# Out:
#                              IMDB_Rating                                  \
#                                    count      mean       std  min    25%
# Genre
# Action, Adventure                    5.0  8.180000  0.286356  7.7  8.200
# Action, Adventure, Biography         1.0  7.900000       NaN  7.9  7.900
# Action, Adventure, Comedy           10.0  7.910000  0.191195  7.6  7.750
# Action, Adventure, Crime             1.0  7.600000       NaN  7.6  7.600
# Action, Adventure, Drama            14.0  8.150000  0.475152  7.6  7.800
# ...                                  ...       ...       ...  ...    ...
# Mystery, Romance, Thriller           1.0  8.300000       NaN  8.3  8.300
# Mystery, Sci-Fi, Thriller            2.0  7.800000  0.282843  7.6  7.700
# Mystery, Thriller                    9.0  7.977778  0.319287  7.6  7.700
# Thriller                             1.0  7.800000       NaN  7.8  7.800
# Western                              4.0  8.350000  0.420317  7.8  8.175
#
# ...

# %%
genre.sample()         #give a random movie in every genre
# Out:
#                    Series_Title Released_Year Certificate  Runtime  \
# 63        The Dark Knight Rises          2012          UA  164 min
# 540    Aguirre, der Zorn Gottes          1972         NaN   95 min
# 722                  Deadpool 2          2018           R  119 min
# 909                   Celda 211          2009         NaN  113 min
# 642   The Count of Monte Cristo          2002       PG-13  131 min
# ..                          ...           ...         ...      ...
# 119                     Vertigo          1958           A  128 min
# 393              Twelve Monkeys          1995           A  129 min
# 829                   Spoorloos          1988         NaN  107 min
# 700             Wait Until Dark          1967         NaN  108 min
# 115  Per qualche dollaro in più          1965           U  132 min
#
#                             Genre  IMDB_Rating  \
# 63              Action, Adventure          8.4
# 540  Action, Adventure, Biography          7.9
# ...

# %%
genre.nunique()
# Out:
#                               Series_Title  Released_Year  Certificate  \
# Genre
# Action, Adventure                        5              5            3
# Action, Adventure, Biography             1              1            0
# Action, Adventure, Comedy               10              8            5
# Action, Adventure, Crime                 1              1            0
# Action, Adventure, Drama                14             11            5
# ...                                    ...            ...          ...
# Mystery, Romance, Thriller               1              1            1
# Mystery, Sci-Fi, Thriller                2              2            1
# Mystery, Thriller                        9              8            4
# Thriller                                 1              1            0
# Western                                  4              4            2
#
#                               Runtime  IMDB_Rating  Overview  Meta_score  \
# Genre
# ...

# %%
genre = movies.groupby('Genre')

# %%
# genre.agg(['min','max','mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
genre.agg(
    {
        'IMDB_Rating':['mean','max'],
        'No_of_Votes':['sum','mean']
    }
)
# Out:
#                              IMDB_Rating      No_of_Votes
#                                     mean  max         sum           mean
# Genre
# Action, Adventure               8.180000  8.4     4627667  925533.400000
# Action, Adventure, Biography    7.900000  7.9       52397   52397.000000
# Action, Adventure, Comedy       7.910000  8.2     4560766  456076.600000
# Action, Adventure, Crime        7.600000  7.6       63882   63882.000000
# Action, Adventure, Drama        8.150000  8.9     9295859  663989.928571
# ...                                  ...  ...         ...            ...
# Mystery, Romance, Thriller      8.300000  8.3      364368  364368.000000
# Mystery, Sci-Fi, Thriller       7.800000  8.0      766370  383185.000000
# Mystery, Thriller               7.977778  8.4     3072266  341362.888889
# Thriller                        7.800000  7.8       27733   27733.000000
# Western                         8.350000  8.8     1289665  322416.250000
#
# [202 rows x 4 columns]

# %%
genre.describe()
# Out:
#                              IMDB_Rating                                  \
#                                    count      mean       std  min    25%
# Genre
# Action, Adventure                    5.0  8.180000  0.286356  7.7  8.200
# Action, Adventure, Biography         1.0  7.900000       NaN  7.9  7.900
# Action, Adventure, Comedy           10.0  7.910000  0.191195  7.6  7.750
# Action, Adventure, Crime             1.0  7.600000       NaN  7.6  7.600
# Action, Adventure, Drama            14.0  8.150000  0.475152  7.6  7.800
# ...                                  ...       ...       ...  ...    ...
# Mystery, Romance, Thriller           1.0  8.300000       NaN  8.3  8.300
# Mystery, Sci-Fi, Thriller            2.0  7.800000  0.282843  7.6  7.700
# Mystery, Thriller                    9.0  7.977778  0.319287  7.6  7.700
# Thriller                             1.0  7.800000       NaN  7.8  7.800
# Western                              4.0  8.350000  0.420317  7.8  8.175
#
# ...

# %%
for group,data in genre:
  print(group)
  print(data)
  break
# Out:
# Action, Adventure
#                            Series_Title Released_Year Certificate  Runtime  \
# 63                The Dark Knight Rises          2012          UA  164 min
# 72              Raiders of the Lost Ark          1981           A  115 min
# 155                       Batman Begins          2005          UA  140 min
# 168  Indiana Jones and the Last Crusade          1989           U  127 min
# 840                         First Blood          1982           A   93 min
#
#                  Genre  IMDB_Rating  \
# 63   Action, Adventure          8.4
# 72   Action, Adventure          8.4
# 155  Action, Adventure          8.2
# 168  Action, Adventure          8.2
# 840  Action, Adventure          7.7
#
#                                               Overview  Meta_score  \
# 63   Eight years after the Joker's reign of anarchy...        78.0
# 72   In 1936, archaeologist and adventurer Indiana ...        85.0
# 155  After training with his mentor, Batman begins ...        70.0
# ...

# %%
print(type(movies))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#built in function
genre.apply(max)
# Out:
# <ipython-input-62-dbf7abc8017c>:2: FutureWarning: The provided callable <built-in function max> is currently using np.maximum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.maximum.reduce instead.
#   genre.apply(max)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, include_groups, *args, **kwargs)
#    1823             try:
# -> 1824                 result = self._python_apply_general(f, self._selected_obj)
#    1825                 if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1884         """
# -> 1885         values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
# ...

# %%
def rank(group):
