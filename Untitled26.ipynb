# %% [markdown]
# <a href="https://colab.research.google.com/github/raj-coding1/EdaAnalysis/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####import required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###Read the data

# %%
df = pd.read_csv('/content/matches.csv')
df.head()
df= df.set_index('id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 636 entries, 1 to 636
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           636 non-null    int64
#  1   city             629 non-null    object
#  2   date             636 non-null    object
#  3   team1            636 non-null    object
#  4   team2            636 non-null    object
#  5   toss_winner      636 non-null    object
#  6   toss_decision    636 non-null    object
#  7   result           636 non-null    object
#  8   dl_applied       636 non-null    int64
#  9   winner           633 non-null    object
#  10  win_by_runs      636 non-null    int64
#  11  win_by_wickets   636 non-null    int64
#  12  player_of_match  633 non-null    object
#  13  venue            636 non-null    object
#  14  umpire1          635 non-null    object
#  15  umpire2          635 non-null    object
#  16  umpire3          0 non-null      float64
# ...

# %%
df.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
df.drop('umpire3',axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 636 entries, 1 to 636
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           636 non-null    int64
#  1   city             629 non-null    object
#  2   date             636 non-null    object
#  3   team1            636 non-null    object
#  4   team2            636 non-null    object
#  5   toss_winner      636 non-null    object
#  6   toss_decision    636 non-null    object
#  7   result           636 non-null    object
#  8   dl_applied       636 non-null    int64
#  9   winner           633 non-null    object
#  10  win_by_runs      636 non-null    int64
#  11  win_by_wickets   636 non-null    int64
#  12  player_of_match  633 non-null    object
#  13  venue            636 non-null    object
#  14  umpire1          635 non-null    object
#  15  umpire2          635 non-null    object
# dtypes: int64(4), object(12)
# ...

# %%
df['season'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='season'>

# %%
df['season'].value_counts().sort_index(ascending=True).plot(kind = 'bar')
# Out:
# <Axes: xlabel='season'>

# %%
df['season'].describe()
# Out:
# count     636.000000
# mean     2012.490566
# std         2.773026
# min      2008.000000
# 25%      2010.000000
# 50%      2012.000000
# 75%      2015.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
df['season'].value_counts().plot(kind = 'pie', autopct = '%0.01f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['city'].describe()
# Out:
# count        629
# unique        30
# top       Mumbai
# freq          85
# Name: city, dtype: object

# %%
df['city'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='city'>

# %%
df['city'].value_counts().plot(kind = 'pie', autopct = '%f0.1ff%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
df['team1'].describe()
# Out:
# count                636
# unique                14
# top       Mumbai Indians
# freq                  82
# Name: team1, dtype: object

# %%
df['team1'].value_counts()
# Out:
# team1
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
df[df['team1'] == 'Rising Pune Supergiant'][['season']]
# Out:
#     season
# id
# 4     2017
# 13    2017
# 17    2017
# 28    2017
# 29    2017
# 33    2017
# 43    2017
# 56    2017

# %%
df['team1'] = df['team1'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df['team1'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['team2'].describe()
# Out:
# count                  636
# unique                  14
# top       Delhi Daredevils
# freq                    84
# Name: team2, dtype: object

# %%
df['team2'].value_counts()
# Out:
# team2
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
df['team2'] = df['team2'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df['team2'].value_counts().plot(kind= 'pie',autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
df['toss_winner'].describe()
# Out:
# count                636
# unique                14
# top       Mumbai Indians
# freq                  85
# Name: toss_winner, dtype: object

# %%
df['toss_winner'] = df['toss_winner'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df['toss_winner'].value_counts().plot(kind = 'pie',autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['toss_decision'].describe()
# Out:
# count       636
# unique        2
# top       field
# freq        363
# Name: toss_decision, dtype: object

# %%
df['toss_decision'].value_counts().plot(kind='pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['result'].describe()
# Out:
# count        636
# unique         3
# top       normal
# freq         626
# Name: result, dtype: object

# %%
df['result'].value_counts()
# Out:
# result
# normal       626
# tie            7
# no result      3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
df['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    620
# 1     16
# Name: count, dtype: int64

# %%
pd.crosstab(df['result'],df['dl_applied'],normalize= 'index')*100
# Out:
# dl_applied           0         1
# result
# no result   100.000000  0.000000
# normal       97.444089  2.555911
# tie         100.000000  0.000000

# %%
df[df['result']=='tie'][['dl_applied']]
# Out:
#      dl_applied
# id
# 34            0
# 126           0
# 190           0
# 388           0
# 401           0
# 476           0
# 536           0

# %%
df['winner'].describe()
# Out:
# count                633
# unique                14
# top       Mumbai Indians
# freq                  92
# Name: winner, dtype: object

# %%
df['winner'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df[df['result'] == 'tie'][['winner']]
# Out:
#                           winner
# id
# 34                Mumbai Indians
# 126             Rajasthan Royals
# 190              Kings XI Punjab
# 388          Sunrisers Hyderabad
# 401  Royal Challengers Bangalore
# 476             Rajasthan Royals
# 536              Kings XI Punjab

# %%
df['win_by_runs'].describe()
# Out:
# count    636.000000
# mean      13.682390
# std       23.908877
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       20.000000
# max      146.000000
# Name: win_by_runs, dtype: float64

# %%
df['win_by_runs'].plot(kind = 'hist', bins = 40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['win_by_runs'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['win_by_runs'].skew()
# Out:
# np.float64(2.5220633095183893)

# %%
df[df['result'] == 'tie' | df['result'] == 'no result'][['win_by_runs']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     361         #  (xint or xbool) and (yint or bool)
# --> 362         result = op(x, y)
#     363     except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/roperator.py in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#      59
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     375             try:
# --> 376                 result = libops.scalar_binop(x, y, op)
#     377             except (
#
# ...

# %%
df[df['result'] == 'no result']
# Out:
#      season       city        date                        team1  \
# id
# 301    2011      Delhi  2011-05-21             Delhi Daredevils
# 546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# id
# 301                Pune Warriors             Delhi Daredevils           bat
# 546             Rajasthan Royals             Rajasthan Royals         field
# 571  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# id
# 301  no result           0    NaN            0               0
# 546  no result           0    NaN            0               0
# 571  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# id
# ...

# %%
df['player_of_match'].describe()
# Out:
# count          633
# unique         201
# top       CH Gayle
# freq            18
# Name: player_of_match, dtype: object

# %%
df['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# RG Sharma            14
#                      ..
# SA Yadav              1
# Mustafizur Rahman     1
# CR Brathwaite         1
# A Zampa               1
# BCJ Cutting           1
# Name: count, Length: 201, dtype: int64

# %%
df[df['player_of_match'] == 'V Kohli'].count()
# Out:
# season             11
# city               11
# date               11
# team1              11
# team2              11
# toss_winner        11
# toss_decision      11
# result             11
# dl_applied         11
# winner             11
# win_by_runs        11
# win_by_wickets     11
# player_of_match    11
# venue              11
# umpire1            11
# umpire2            11
# umpire3             0
# dtype: int64

# %%
df['player_of_match']
# Out:
# id
# 1        Yuvraj Singh
# 2           SPD Smith
# 3             CA Lynn
# 4          GJ Maxwell
# 5           KM Jadhav
#             ...
# 632           V Kohli
# 633    AB de Villiers
# 634      MC Henriques
# 635         DA Warner
# 636       BCJ Cutting
# Name: player_of_match, Length: 636, dtype: object

# %%
df['venue'].describe()
# Out:
# count                       636
# unique                       35
# top       M Chinnaswamy Stadium
# freq                         66
# Name: venue, dtype: object

# %%
df['venue'].value_counts()
# Out:
# venue
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# ...

# %%
df['umpire1'].describe()
# Out:
# count                 635
# unique                 44
# top       HDPK Dharmasena
# freq                   73
# Name: umpire1, dtype: object

# %%
df[df['umpire1'].isnull()]
# Out:
#     season       city        date                        team1  \
# id
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                team2                  toss_winner toss_decision  result  \
# id
# 5   Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#     dl_applied                       winner  win_by_runs  win_by_wickets  \
# id
# 5            0  Royal Challengers Bangalore           15               0
#
#    player_of_match                  venue umpire1 umpire2  umpire3
# id
# 5        KM Jadhav  M Chinnaswamy Stadium     NaN     NaN      NaN

# %%
df['umpire1'].value_counts()
# Out:
# umpire1
# HDPK Dharmasena          73
# Asad Rauf                51
# AK Chaudhary             43
# Aleem Dar                38
# BF Bowden                37
# S Ravi                   36
# BR Doctrove              34
# M Erasmus                32
# RE Koertzen              20
# S Asnani                 19
# JD Cloete                16
# CB Gaffaney              14
# BG Jerling               13
# AY Dandekar              13
# NJ Llong                 12
# SS Hazare                11
# A Nand Kishore           11
# Nitin Menon              11
# VA Kulkarni              11
# KN Ananthapadmanabhan    11
# RK Illingworth           11
# S Das                    10
# MR Benson                10
# K Hariharan              10
# DJ Harper                 9
# BNJ Oxenford              7
# IL Howell                 7
# RM Deshpande              7
# GAV Baxter                7
# C Shamshuddin             6
# SJ Davis                  6
# CK Nandan                 5
# SD Fry                    5
# ...
